# %%
# !python sample.py --config=./configs/DiffuseStyleGesture.yml --no_cuda 0 --gpu 0 --model_path "./model000450000.pt" --audiowavlm_path "./021_Happy_4_x_1_0.wav"
# Out:
# {'audio_feat': 'wavlm',
#  'audiowavlm_path': './021_Happy_4_x_1_0.wav',
#  'batch_size': 300,
#  'betas': [0.5, 0.999],
#  'config': './configs/DiffuseStyleGesture.yml',
#  'data_mean': '../../ubisoft-laforge-ZeroEGGS-main/data/processed_v1/processed/mean.npz',
#  'data_std': '../../ubisoft-laforge-ZeroEGGS-main/data/processed_v1/processed/std.npz',
#  'epochs': 500,
#  'gamma': 0.1,
#  'gpu': '0',
#  'loader_workers': 2,
#  'log_interval': 50,
#  'lr': 3e-05,
#  'lr_anneal_steps': 0,
#  'max_len': 0,
#  'milestones': [100, 200],
#  'model_path': './model000450000.pt',
#  'model_save_path': './output/train_DiffuseStyleGesture',
#  'motion_resampling_framerate': 20,
#  'n_codes': 30,
#  'n_poses': 88,
#  'name': 'DiffuseStyleGesture',
#  'no_cuda': ['0'],
#  'save_dir': './zeggs_mymodel3_wavlm',
#  'save_per_epochs': 25,
#  'subdivision_stride': 10,
#  'train_data_path': '../../ubisoft-laforge-ZeroEGGS-main/data/processed_v1/processed/train/train_lmdb/train_lmdb/',
# ...

# %%
# !python sample.py --config=./configs/DiffuseStyleGesture.yml --no_cuda 0 --gpu 0 --model_path "./model000450000.pt" --audiowavlm_path "./022_Happy_4_x_1_0.wav"
# Out:
# {'audio_feat': 'wavlm',
#  'audiowavlm_path': './022_Happy_4_x_1_0.wav',
#  'batch_size': 300,
#  'betas': [0.5, 0.999],
#  'config': './configs/DiffuseStyleGesture.yml',
#  'data_mean': '../../ubisoft-laforge-ZeroEGGS-main/data/processed_v1/processed/mean.npz',
#  'data_std': '../../ubisoft-laforge-ZeroEGGS-main/data/processed_v1/processed/std.npz',
#  'epochs': 500,
#  'gamma': 0.1,
#  'gpu': '0',
#  'loader_workers': 2,
#  'log_interval': 50,
#  'lr': 3e-05,
#  'lr_anneal_steps': 0,
#  'max_len': 0,
#  'milestones': [100, 200],
#  'model_path': './model000450000.pt',
#  'model_save_path': './output/train_DiffuseStyleGesture',
#  'motion_resampling_framerate': 20,
#  'n_codes': 30,
#  'n_poses': 88,
#  'name': 'DiffuseStyleGesture',
#  'no_cuda': ['0'],
#  'save_dir': './zeggs_mymodel3_wavlm',
#  'save_per_epochs': 25,
#  'subdivision_stride': 10,
#  'train_data_path': '../../ubisoft-laforge-ZeroEGGS-main/data/processed_v1/processed/train/train_lmdb/train_lmdb/',
# ...
